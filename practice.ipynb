# %%
from multiprocessing.reduction import duplicate

#Reverse a string without using slicing ([::-1]).
STR = "madam"
Reverse_Str = ""
for char in STR:
    Reverse_Str = char+Reverse_Str

# %%
Reverse_Str == STR
# Out:
# True

# %%
#Check whether a string is a palindrome.

str_input=str(input("enter the string"))

# if str_input == str_input[::-1]:
#     print("The string is reversed")
# else:
#     print("The string is not reversed")

reversed_string= ""
for char in str_input:
    reversed_string =char+reversed_string
print(reversed_string)

if str_input==reversed_string:
    print("its a palindrom")
else:
    print("not a palindrom")
# Out:
# hseyaj
# not a palindrom

# %%
items = [1, 2, 3, 4, 5, 6]
b=[1,2,3]
c=items+b
set(items+b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
from collections import Counter
items ="jayeshh"
count = Counter(items)
count
# Out:
# Counter({'h': 2, 'j': 1, 'a': 1, 'y': 1, 'e': 1, 's': 1})

# %%
items ="jayesh"

duplicate=[]
seen =[]

for i in items:
    if i in seen and i not in duplicate:
        duplicate.append(i)
    else:
        seen.append(i)

# %%
duplicate
# Out:
# ['h']

# %%
seen
# Out:
# ['j', 'a', 'y', 'e', 's', 'h']

# %%
numbers = [1, 2, 3, 2, 4, 1, 5, 3]

# %%
set(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
unique = []
for i in numbers:
    if i not in unique:
        unique.append(i)

# %%
unique
# Out:
# [1, 2, 3, 4, 5]

# %%
from collections import Counter
item = [2,4,5,6,3,2,1,1]
count = Counter(item)
count
# Out:
# Counter({2: 2, 1: 2, 4: 1, 5: 1, 6: 1, 3: 1})

# %%
duplicate = []
seen = []
for i in item:
    if i in seen and i not in duplicate:
        duplicate.append(i)
    else:
        seen.append(i)

# %%
duplicate
# Out:
# [2, 1]

# %%
a="jayesh"
b=""
for i in a:
    b=i+b

b
# Out:
# 'hseyaj'

# %%
a=[1,2,1,3,2,4,5,6]

unique=[]
for i in a:
    if i not in unique:
        unique.append(i)
unique
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
dict1 = {"a": 10, "b": 20}
dict2 = {"c": 50, "c": 30,"d" : 23 }

dict1.update(dict2)

# %%
dict1
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 23}

# %%
merged = {**dict1, **dict2}
print(merged)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 23}

# %%
nested_list = [[1, 2], [3, 4], [5, 6]]

normal = []

for i in nested_list:
    for j in i :
        normal.append(j)

# %%
normal
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
number = [10, 25, 7, 40, 18]
number.sort()
number[-2]
# Out:
# 25

# %%
max(number)
# Out:
# 40

# %%
number = [10, 25, 7, 40, 18]
large= number[0]
s_large = number[0]

for i in number:
    if i >large:
        large = i
for i in number:
    if i > s_large and i!=large:
        s_large = i

# %%
large
# Out:
# 40

# %%
s_large
# Out:
# 25

# %%
#reverse string

a="jayesh"
b="mahesh"

count1= {}
count2 ={}

for i in a:
    if i in count1:
        count1[i]+=1
    else:
        count1[i]+1
print("count1")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 13
#      11         count1[i]+=1
#      12     else:
# ---> 13         count1[i]+1
#      14 print("count1")
#
# KeyError: 'j'

# %%
num = 7
if num <= 1:
    print("number is not prime")
else:
    for i in range(2,num):
        if num % i ==0:
            print("number is not prime")
            break
    else:
        print("number is prime")
# Out:
# number is prime

# %%
year = 1000

if year % 400 ==0 :
    print("leap year")
elif year % 100==0:
    print("not a leap year")
elif year % 4==0:
    print("leap year")
else:
    print("not a leap year")
# Out:
# not a leap year

# %%
num = 5
a=1
b=1
for i in range(num+1):
    print(a)
    c=a+b
    a=b
    b=c
# Out:
# 1
# 1
# 2
# 3
# 5
# 8

# %%
from collections import Counter
a=[2,3,2,5,1,56,2,3]
print("this is using counter class = ", Counter(a))

count={}

for i in a:
    if i in count:
        count[i] +=1
    else:
        count[i]=1
print(count)
# Out:
# this is using counter class =  Counter({2: 3, 3: 2, 5: 1, 1: 1, 56: 1})
# {2: 3, 3: 2, 5: 1, 1: 1, 56: 1}

# %%
num = 5
factorial =1

for i in range(1,num+1):
    factorial*=i
print(factorial)
# Out:
# 120

# %%
employees= [
      {"id":1,"name":"A","salary":120000},
      {"id":2,"name":"B","salary":90000},
      {"id":3,"name":"C","salary":180000}
  ]
type(employees)
# Out:
# list

# %%
for i in employees:
    print(i["salary"]>100000)
# Out:
# True
# False
# True
