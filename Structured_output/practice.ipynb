# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
from typing import Optional,Annotated,Literal
import pydantic
from pydantic import BaseModel,Field
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
class Review(BaseModel):
    Key_points :list[str] = Field(description="List down all the key factors of the review which are discussed")
    Pros:Optional[list[str]] = Field(description="list down all the pros of the review which are discussed")
    Cons:Optional[list[str]] = Field(description="list down all the cons of the review which are discussed")
    Sentiment:Literal["positive","negative"] = Field(description="list down the sentiment of the review ")
    Summary:str=Field(description="list down the summary of the review in brief")

Structured_model = model.with_structured_output(Review)

result=Structured_model.invoke("""The hardware is great, but the software feels bloated.
There are too many pre-installed apps that I can’t remove. Also, the UI looks outdated compared to other brands. Hoping for a software update to fix this.

I recently upgraded to the Samsung Galaxy S24 Ultra, and I must say, it’s an absolute powerhouse! The Snapdragon 8 Gen 3 processor makes everything lightning fast—whether I’m gaming, multitasking, or editing photos. The 5000mAh battery easily lasts a full day even with heavy use, and the 45W fast charging is a lifesaver.

The S-Pen integration is a great touch for note-taking and quick sketches, though I don’t use it often. What really blew me away is the 200MP camera—the night mode is stunning, capturing crisp, vibrant images even in low light. Zooming up to 100x actually works well for distant objects, but anything beyond 30x loses quality.

However, the weight and size make it a bit uncomfortable for one-handed use. Also, Samsung’s One UI still comes with bloatware—do I really need five different Samsung apps for things Google already provides? The $1,300 price tag is also a hard pill to swallow.

Pros:

Insanely powerful processor (great for gaming and productivity)

Stunning 200MP camera with incredible zoom capabilities

Long battery life with fast charging

S-Pen support is unique and useful

Cons:

Bulky and heavy – not great for one-handed use

Bloatware still exists in One UI

Expensive compared to competitors""")

# %%
print(result)
# Out:
# Key_points=['Processor speed', 'Battery life', 'Charging speed', 'S-Pen integration', 'Camera quality (200MP, night mode, zoom)', 'Device weight and size', 'Bloatware in One UI', 'Price'] Pros=['Snapdragon 8 Gen 3 processor makes everything fast', '5000mAh battery lasts a full day with heavy use', '45W fast charging is a lifesaver', 'S-Pen integration is great for note-taking and sketches', '200MP camera with stunning night mode', '100x zoom works well for distant objects'] Cons=['Weight and size make it uncomfortable for one-handed use', 'One UI still comes with bloatware', 'Expensive at $1,300'] Sentiment='positive' Summary='The Samsung Galaxy S24 Ultra is a powerful device with a fast processor, excellent battery life, and an impressive 200MP camera. While the S-Pen is a nice addition and the zoom is capable, the phone is bulky, suffers from bloatware, and comes with a high price tag.'
