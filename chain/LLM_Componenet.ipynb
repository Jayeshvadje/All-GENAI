# %%
from Sequential_chain import template
import random

class naklillm :
    def __init__(self):
        print("llm created")
    def predict (self,prompt):

        response_list = [
            "delhi is the capital of india",
            "ipl is a cricket leauge",
            "ai stand for Artificaial intaligence"
        ]

        return {"response":random.choice(response_list)}

# %%
llm = naklillm()
# Out:
# llm created

# %%
llm.predict("what is the capital of india")
# Out:
# {'response': 'ai stand for Artificaial intaligence'}

# %%
class Nakliprompytemplate:
    def __init__(self,template, input_variables):
        self.template = template
        self.input_variables = input_variables

    def format(self,input_dict):
        return  self.template.format(**input_dict)

# %%
template= Nakliprompytemplate(template="write a {length} poem about {topic}",input_variables=["length","topic"])

prompt = template.format({"length":"short","topic": "india",})

# %%
llm=naklillm()
result = llm.predict(prompt)
# Out:
# llm created

# %%
result
# Out:
# {'response': 'ipl is a cricket leauge'}
